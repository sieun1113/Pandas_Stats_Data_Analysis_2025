# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/Data_Analysis/blob/main/3_Slicing_Advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**🔖 Index operators loc[ ] & iloc[ ]**
#
# **원소 선택**
# * DataFrameObject.loc[row행인덱스, column열이름]
# * DataFrameObject.iloc[row행번호, column열번호]
#
#
# **범위 슬라이싱 활용**
#
# * DataFrameObject.iloc[시작인덱스:끝인덱스:슬라이싱간격]
# * The first colon : indicates that we're selecting all rows.
# * The second colon : indicates the step size, which is

# %%
#@markdown  **🐹 Student Activity 8 of the Previous Class Material ⤵️**

#@markdown  **Choose a column 열 선택**

#@markdown  **column name[]**

import pandas as pd

exam_data = {'Math':[90, 80, 70, 85], 'English':[98, 89, 95, 79],
             'Music':[85, 95, 100, 100], 'Gym':[100,90,90, 88]}

df = pd.DataFrame(exam_data, index = ['Simon', 'Emma', 'Mary', 'Louis'])

print(df)
print('\n')

math1 = df['Math']
print(math1)
print('\n')
print(type(math1))

eng1 = df['English']
print(eng1)
print('\n')
print(type(eng1))
# Out:
#        Math  English  Music  Gym
# Simon    90       98     85  100
# Emma     80       89     95   90
# Mary     70       95    100   90
# Louis    85       79    100   88
#
#
# Simon    90
# Emma     80
# Mary     70
# Louis    85
# Name: Math, dtype: int64
#
#
# <class 'pandas.core.series.Series'>
# Simon    98
# Emma     89
# Mary     95
# Louis    79
# Name: English, dtype: int64
#
#
# <class 'pandas.core.series.Series'>

# %%
#@markdown  **🐹 Student Activity 1 ⤵️**

#@markdown  **Select rows 복수행 선택**

#@markdown  **Row name[] with colon symbols**

#@markdown <font color = 'brown'> **📊 When we get tables with _index operator_ based on integer location, iloc[ ], directly, we also get various table formats such as CSV, JSON, & markdown and graphs.**


import pandas as pd

exam_data = {'Math':[90, 80, 70, 85], 'English':[98, 89, 95, 79],
             'Music':[85, 95, 100, 100], 'Gym':[100,90,90, 88]}

df = pd.DataFrame(exam_data, index = ['Simon', 'Emma', 'Mary', 'Louis'])

df.iloc[::2]
# Out:
#        Math  English  Music  Gym
# Simon    90       98     85  100
# Mary     70       95    100   90

# %%
#@markdown  **🐹 Student Activity 1_1 ⤵️**

#@markdown  **Select rows 복수행 선택**

#@markdown  **Row name[] with colon symbols**

import pandas as pd

exam_data = {'Math':[90, 80, 70, 85], 'English':[98, 89, 95, 79],
             'Music':[85, 95, 100, 100], 'Gym':[100,90,90, 88]}

df = pd.DataFrame(exam_data, index = ['Simon', 'Emma', 'Mary', 'Louis'])

df.iloc[0:3:2]
# Out:
#        Math  English  Music  Gym
# Simon    90       98     85  100
# Mary     70       95    100   90

# %%
#@markdown  **🐹 Student Activity 1_2 ⤵️**

#@markdown  **Select rows 복수행 선택**

#@markdown  **Row name[] with the colon symbols**

import pandas as pd

exam_data = {'Math':[90, 80, 70, 85], 'English':[98, 89, 95, 79],
             'Music':[85, 95, 100, 100], 'Gym':[100,90,90, 88]}

df = pd.DataFrame(exam_data, index = ['Simon', 'Emma', 'Mary', 'Louis'])

#The first colon : indicates that we're selecting all rows.
#The second colon : indicates the step size, which is -1. A step size of -1 means we're traversing the array in reverse order.
df.iloc[::-1]
# Out:
#        Math  English  Music  Gym
# Louis    85       79    100   88
# Mary     70       95    100   90
# Emma     80       89     95   90
# Simon    90       98     85  100

# %%
#@markdown  **🐹 Student Activity 1_3 ⤵️**

#@markdown  **Select rows 복수행 선택**

#@markdown  **Row names selected [ ] with the colon symbols**

import pandas as pd

exam_data = {'Math':[90, 80, 70, 85], 'English':[98, 89, 95, 79],
             'Music':[85, 95, 100, 100], 'Gym':[100,90,90, 88]}

df = pd.DataFrame(exam_data, index = ['Simon', 'Emma', 'Mary', 'Louis'])

#You will only get the last code line of >> df.iloc[::-1]
df.iloc[::2]
df.iloc[0:3:2]
df.iloc[::-1]
# Out:
#        Math  English  Music  Gym
# Louis    85       79    100   88
# Mary     70       95    100   90
# Emma     80       89     95   90
# Simon    90       98     85  100

# %%
#@markdown  **🐹 Student Activity 1_4 ⤵️**

#@markdown  **Select rows 복수행 선택**

#@markdown  **column name[] with the colon symbol**

import pandas as pd

exam_data = {'Math':[90, 80, 70, 85], 'English':[98, 89, 95, 79],
             'Music':[85, 95, 100, 100], 'Gym':[100,90,90, 88]}

df = pd.DataFrame(exam_data, index = ['Simon', 'Emma', 'Mary', 'Louis'])

#How can you get all three tables?
df1 = df.iloc[::2]
df2 = df.iloc[0:3:2]
df3 = df.iloc[::-1]

print(df1)
print('\n')
print(df2)
print('\n')
print(df3)
# Out:
#        Math  English  Music  Gym
# Simon    90       98     85  100
# Mary     70       95    100   90
#
#
#        Math  English  Music  Gym
# Simon    90       98     85  100
# Mary     70       95    100   90
#
#
#        Math  English  Music  Gym
# Louis    85       79    100   88
# Mary     70       95    100   90
# Emma     80       89     95   90
# Simon    90       98     85  100
